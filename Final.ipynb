# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/BasicProg_DataViz65/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#เชื่อม google drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Final

# %% [markdown]
# ข้อสอบจำนวน 1 ข้อ คะแนน 120 เต็ม 100 คะแนน
#
# จุดมุ่งหมาย: ตัดเกรดรายวิชา Project และวาดกราฟแสดงผลการสอบดังรายละเอียดต่อไปนี้
#
# ดาวน์โหลดไฟล์คะแนนทั้งหมดจาก https://drive.google.com/drive/folders/1YB4qdluEN8dCE7vhDrNOW40JoUDyeEyL?usp=sharing
#
# รวมคะแนนและตัดเกรดแบบ อิงเกณฑ์ <50 ได้ F ... >= 80 ได้ A และ save ตาราง ชื่อ
#
# *คะแนนรวม 60 คะแนน (ข้อละ 20 คะแนน)*

# %% [markdown]
# #1.คะแนนประกอบด้วย 2 ส่วน

# %% [markdown]
# * คะแนน 40% จากอาจารย์ที่ปรึกษา (จากไฟล์ คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx)
# * คะแนน 60% จากกรรมการในห้องโดยมีการสอบทั้งหมดสามวันอยู่คนละ sheet (จากไฟล์ คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx) *(คะแนนจากกรรมการในห้องจะประกอบไปด้วยคะแนนจากกรรมการ 2 ท่าน ท่านละ 30%)*

# %% [markdown]
# #ตารางอาจารย์ที่ปรึกษา 40 %

# %%
df1 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.ธนพงศ์',skiprows=1)
df2 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.ธิปไตย',skiprows=1)
df3 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.พลากร',skiprows=1)
df4 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.วรรณพร',skiprows=1)
df5 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.อุทุมพร',skiprows=1)
df6 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ผศ.วุฒิชัย',skiprows=1)
df7 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ผศ.สุกัญญา',skiprows=1)
df8 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.วิชุดา',skiprows=1)
df9 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='อ.ธรรณญพร',skiprows=1)
df10 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='อ.ยุภาพร',skiprows=1)
df11 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.ธิดาเดียว',skiprows=1)
df12 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.สุพรรณี',skiprows=1)

# %%
alladvisor = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12])
alladvisor
# Out:
#                        Unnamed: 0  \
# 0                             NaN
# 1             jumpy-apricot-frise
# 2        boozy-thistle-wildebeest
# 3            hasty-magnolia-devil
# 4         chummy-goldenrod-walrus
# ..                            ...
# 4                randy-mauve-ibis
# 5                hazy-beige-stoat
# 6   squirrely-seashell-kingfisher
# 7               surly-linen-hyena
# 8                nippy-lilac-chin
#
#     1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                 5.0
# 1                                                 5.0
# 2                                                 4.0
# 3                                                 5.0
# 4                                                 5.0
# ..                                                ...
# 4                                                 NaN
# 5                                                 NaN
# ...

# %%
alladvisor.columns
# Out:
# Index(['Unnamed: 0',
#        '1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ',
#        '2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย',
#        '3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา',
#        '4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)',
#        '5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว',
#        '6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน',
#        '7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน',
#        'ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)',
#        'ความสมบูรณ์ของเล่ม (8.2 ความสามารถในการคิด วิเคราะห์ หรือสังเคราะห์งาน )',
#        'ความสมบูรณ์ของเล่ม (8.3 ความสวยงาม ประณีต และความเหมาะสมของรายงาน)',
#        'รวม', 'Unnamed: 12'],
#       dtype='object')

# %%
alladvisor = alladvisor[['Unnamed: 0', 'รวม']].dropna()

# %%
alladvisor.rename(columns = {'Unnamed: 0' : 'นักศึกษา'}, inplace = True)
alladvisor
# Out:
#                          นักศึกษา   รวม
# 1             jumpy-apricot-frise  67.0
# 2        boozy-thistle-wildebeest  64.0
# 3            hasty-magnolia-devil  67.0
# 4         chummy-goldenrod-walrus  67.0
# 5              randy-gamboge-blue  61.0
# ..                            ...   ...
# 4                randy-mauve-ibis  63.0
# 5                hazy-beige-stoat  50.0
# 6   squirrely-seashell-kingfisher  50.0
# 7               surly-linen-hyena  50.0
# 8                nippy-lilac-chin  62.0
#
# [80 rows x 2 columns]

# %%
alladvisor['คะแนน(40%)'] = (40*alladvisor['รวม']/70)
alladvisor
# Out:
#                          นักศึกษา   รวม  คะแนน(40%)
# 1             jumpy-apricot-frise  67.0   38.285714
# 2        boozy-thistle-wildebeest  64.0   36.571429
# 3            hasty-magnolia-devil  67.0   38.285714
# 4         chummy-goldenrod-walrus  67.0   38.285714
# 5              randy-gamboge-blue  61.0   34.857143
# ..                            ...   ...         ...
# 4                randy-mauve-ibis  63.0   36.000000
# 5                hazy-beige-stoat  50.0   28.571429
# 6   squirrely-seashell-kingfisher  50.0   28.571429
# 7               surly-linen-hyena  50.0   28.571429
# 8                nippy-lilac-chin  62.0   35.428571
#
# [80 rows x 3 columns]

# %% [markdown]
# #ตารางกรรมการทั้ง 3 วัน

# %%
day7 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=0,skiprows=1)
day8 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=1,skiprows=1)
day9 = pd.read_excel('/content/drive/MyDrive/FinalDataViz65/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=2,skiprows=1)

# %%
day7_1 = day7.fillna(method='ffill')
day8_1 = day8.fillna(method='ffill')
day9_1 = day9.fillna(method='ffill')

# %%
committee = pd.concat([day7_1,day8_1,day9_1])
committee
# Out:
#     ห้องสอบ              เวลา  \
# 0       NaN               NaN
# 1   SC 6501  08:00 – 10.00 น.
# 2   SC 6501  08:00 – 10.00 น.
# 3   SC 6501  08:00 – 10.00 น.
# 4   SC 6501  08:00 – 10.00 น.
# ..      ...               ...
# 50  SC 6410  10:00 – 12.00 น.
# 51  SC 6410  13:00 – 15.00 น.
# 52  SC 6410  13:00 – 15.00 น.
# 53  SC 6410  13:00 – 15.00 น.
# 54  SC 6410  13:00 – 15.00 น.
#
#                                            ชื่อเรื่อง  \
# 0                                                 NaN
# 1   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...
# 2   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...
# 3   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...
# 4   1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...
# ..                                                ...
# 50  41.ตัวแบบการพยากรณ์ปริมาณการส่งออกข้าวรายเดือน...
# 51  42.การพัฒนาระบบสารสนเทศการสั่งอาหารร้านปลาวาฬใ...
# 52  42.การพัฒนาระบบสารสนเทศการสั่งอาหารร้านปลาวาฬใ...
# ...

# %%
committee.columns
# Out:
# Index(['ห้องสอบ', 'เวลา', 'ชื่อเรื่อง', 'นักศึกษา', 'อาจารย์', 'กรรมการสอบ',
#        'ความชัดเจนของโจทย์การวิจัย',
#        'ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง',
#        'ความถูกต้องของระเบียบวิธีวิจัย', 'สื่อการนำเสนอ',
#        'ความสามารถในการนำเสนอและตอบคำถาม', 'ความถูกต้องของเนื้อหาในเล่มรายงาน',
#        'รวม'],
#       dtype='object')

# %%
committee = committee[['นักศึกษา','อาจารย์','กรรมการสอบ','รวม']]
committee
# Out:
#                        นักศึกษา    อาจารย์  กรรมการสอบ  รวม
# 0                           NaN  ที่ปรึกษา         NaN   70
# 1          leaky-rust-chameleon  ดร.ธิปไตย  ผศ.วุฒิชัย   52
# 2            greasy-ruby-bombay  ดร.ธิปไตย  ผศ.วุฒิชัย   50
# 3          leaky-rust-chameleon  ดร.ธิปไตย    อ.ยุภาพร   60
# 4            greasy-ruby-bombay  ดร.ธิปไตย    อ.ยุภาพร   58
# ..                          ...        ...         ...  ...
# 50         muggy-charcoal-akita   ดร.พลากร  ผศ.วุฒิชัย   52
# 51  stinky-wisteria-nightingale   ดร.พลากร   รศ.วิชุดา   57
# 52            hazy-aqua-peccary   ดร.พลากร   รศ.วิชุดา   57
# 53  stinky-wisteria-nightingale   ดร.พลากร   ดร.ธนพงศ์   59
# 54            hazy-aqua-peccary   ดร.พลากร   ดร.ธนพงศ์   59
#
# [163 rows x 4 columns]

# %% [markdown]
# Point
#     เลือกคะแนนน้อยและมากในนักศึกษาแต่ละคน แล้วรวมตาราง
#     จะได้ผลลัพธ์เป็นค่าคะแนนที่กรรมการทั้ง 2 ให้นักศึกษา

# %%
min = committee.groupby('นักศึกษา').min()

# %%
max = committee.groupby('นักศึกษา').max()

# %%
score = max.merge(min, left_on='นักศึกษา',right_on='นักศึกษา').reset_index()
score
# Out:
#                     นักศึกษา   อาจารย์_x  กรรมการสอบ_x  รวม_x   อาจารย์_y  \
# 0   boozy-thistle-wildebeest   ดร.ธนพงศ์     รศ.วิชุดา     58   ดร.ธนพงศ์
# 1          breezy-pear-macaw  ดร.อุทุมพร  รศ.ธิดาเดียว     56  ดร.อุทุมพร
# 2       bumpy-indigo-dolphin   ดร.ธิปไตย      อ.ยุภาพร     58   ดร.ธิปไตย
# 3          chewy-lilac-shark   อ.ธรรณญพร    รศ.สุพรรณี     61   อ.ธรรณญพร
# 4    chewy-persimmon-catfish  รศ.สุพรรณี     อ.ธรรณญพร     48  รศ.สุพรรณี
# ..                       ...         ...           ...    ...         ...
# 75    ugly-harlequin-octopus   รศ.วิชุดา      อ.ยุภาพร     59   รศ.วิชุดา
# 76        ugly-myrtle-walrus   อ.ธรรณญพร    รศ.สุพรรณี     52   อ.ธรรณญพร
# 77       whiny-peach-audemer    อ.ยุภาพร    ดร.อุทุมพร     51    อ.ยุภาพร
# 78          whiny-pear-otter  ผศ.สุกัญญา     อ.ธรรณญพร     60  ผศ.สุกัญญา
# 79       wiggy-silver-drever   ดร.ธิปไตย      อ.ยุภาพร     52   ดร.ธิปไตย
#
#    กรรมการสอบ_y  รวม_y
# 0      ดร.พลากร     57
# 1     ดร.วรรณพร     56
# ...

# %% [markdown]
# rename columns

# %%
score.rename(columns = {'อาจารย์_x' : 'อาจารย์', 'กรรมการสอบ_x':'กรรมการ 1', 'กรรมการสอบ_y':'กรรมการ 2', 'รวม_x':'คะแนนกรรมการที่ 1', 'รวม_y':'คะแนนกรรมการที่ 2'}, inplace = True)
score
# Out:
#                     นักศึกษา     อาจารย์     กรรมการ 1  คะแนนกรรมการที่ 1  \
# 0   boozy-thistle-wildebeest   ดร.ธนพงศ์     รศ.วิชุดา                 58
# 1          breezy-pear-macaw  ดร.อุทุมพร  รศ.ธิดาเดียว                 56
# 2       bumpy-indigo-dolphin   ดร.ธิปไตย      อ.ยุภาพร                 58
# 3          chewy-lilac-shark   อ.ธรรณญพร    รศ.สุพรรณี                 61
# 4    chewy-persimmon-catfish  รศ.สุพรรณี     อ.ธรรณญพร                 48
# ..                       ...         ...           ...                ...
# 75    ugly-harlequin-octopus   รศ.วิชุดา      อ.ยุภาพร                 59
# 76        ugly-myrtle-walrus   อ.ธรรณญพร    รศ.สุพรรณี                 52
# 77       whiny-peach-audemer    อ.ยุภาพร    ดร.อุทุมพร                 51
# 78          whiny-pear-otter  ผศ.สุกัญญา     อ.ธรรณญพร                 60
# 79       wiggy-silver-drever   ดร.ธิปไตย      อ.ยุภาพร                 52
#
#      อาจารย์_y   กรรมการ 2  คะแนนกรรมการที่ 2
# ...

# %% [markdown]
# ##คะแนนกรรมการคนที่ 1 และ 2
# คิดเป็น 30% และนำมา บวกกัน ได้ 60%

# %%
score['คะแนนกรรมการที่ 1 (30%)'] = (30*score['คะแนนกรรมการที่ 1']/70)

# %%
score['คะแนนกรรมการที่ 2 (30%)'] = (30*score['คะแนนกรรมการที่ 2']/70)

# %%
score['คะแนนรวม (60%)'] = score['คะแนนกรรมการที่ 1 (30%)'] + score['คะแนนกรรมการที่ 2 (30%)']
score
# Out:
#                     นักศึกษา     อาจารย์     กรรมการ 1  คะแนนกรรมการที่ 1  \
# 0   boozy-thistle-wildebeest   ดร.ธนพงศ์     รศ.วิชุดา                 58
# 1          breezy-pear-macaw  ดร.อุทุมพร  รศ.ธิดาเดียว                 56
# 2       bumpy-indigo-dolphin   ดร.ธิปไตย      อ.ยุภาพร                 58
# 3          chewy-lilac-shark   อ.ธรรณญพร    รศ.สุพรรณี                 61
# 4    chewy-persimmon-catfish  รศ.สุพรรณี     อ.ธรรณญพร                 48
# ..                       ...         ...           ...                ...
# 75    ugly-harlequin-octopus   รศ.วิชุดา      อ.ยุภาพร                 59
# 76        ugly-myrtle-walrus   อ.ธรรณญพร    รศ.สุพรรณี                 52
# 77       whiny-peach-audemer    อ.ยุภาพร    ดร.อุทุมพร                 51
# 78          whiny-pear-otter  ผศ.สุกัญญา     อ.ธรรณญพร                 60
# 79       wiggy-silver-drever   ดร.ธิปไตย      อ.ยุภาพร                 52
#
#      อาจารย์_y   กรรมการ 2  คะแนนกรรมการที่ 2  คะแนนกรรมการที่ 1 (30%)  \
# ...

# %% [markdown]
# #รวมตาราง
# อาจารย์ 40% กับตารางกรรมการ 60% ทั้ง 3 วัน

# %%
score.head()
# Out:
#                    นักศึกษา     อาจารย์     กรรมการ 1  คะแนนกรรมการที่ 1  \
# 0  boozy-thistle-wildebeest   ดร.ธนพงศ์     รศ.วิชุดา                 58
# 1         breezy-pear-macaw  ดร.อุทุมพร  รศ.ธิดาเดียว                 56
# 2      bumpy-indigo-dolphin   ดร.ธิปไตย      อ.ยุภาพร                 58
# 3         chewy-lilac-shark   อ.ธรรณญพร    รศ.สุพรรณี                 61
# 4   chewy-persimmon-catfish  รศ.สุพรรณี     อ.ธรรณญพร                 48
#
#     อาจารย์_y   กรรมการ 2  คะแนนกรรมการที่ 2  คะแนนกรรมการที่ 1 (30%)  \
# 0   ดร.ธนพงศ์    ดร.พลากร                 57                24.857143
# 1  ดร.อุทุมพร   ดร.วรรณพร                 56                24.000000
# 2   ดร.ธิปไตย  ผศ.วุฒิชัย                 49                24.857143
# 3   อ.ธรรณญพร  ผศ.สุกัญญา                 50                26.142857
# 4  รศ.สุพรรณี  ผศ.สุกัญญา                 47                20.571429
#
#    คะแนนกรรมการที่ 2 (30%)  คะแนนรวม (60%)
# 0                24.428571       49.285714
# ...

# %%
alladvisor.head()
# Out:
#                    นักศึกษา   รวม  คะแนน(40%)
# 1       jumpy-apricot-frise  67.0   38.285714
# 2  boozy-thistle-wildebeest  64.0   36.571429
# 3      hasty-magnolia-devil  67.0   38.285714
# 4   chummy-goldenrod-walrus  67.0   38.285714
# 5        randy-gamboge-blue  61.0   34.857143

# %%
All = score.merge(alladvisor, left_on='นักศึกษา', right_on='นักศึกษา')
All
# Out:
#                     นักศึกษา     อาจารย์     กรรมการ 1  คะแนนกรรมการที่ 1  \
# 0   boozy-thistle-wildebeest   ดร.ธนพงศ์     รศ.วิชุดา                 58
# 1          breezy-pear-macaw  ดร.อุทุมพร  รศ.ธิดาเดียว                 56
# 2       bumpy-indigo-dolphin   ดร.ธิปไตย      อ.ยุภาพร                 58
# 3          chewy-lilac-shark   อ.ธรรณญพร    รศ.สุพรรณี                 61
# 4    chewy-persimmon-catfish  รศ.สุพรรณี     อ.ธรรณญพร                 48
# ..                       ...         ...           ...                ...
# 75    ugly-harlequin-octopus   รศ.วิชุดา      อ.ยุภาพร                 59
# 76        ugly-myrtle-walrus   อ.ธรรณญพร    รศ.สุพรรณี                 52
# 77       whiny-peach-audemer    อ.ยุภาพร    ดร.อุทุมพร                 51
# 78          whiny-pear-otter  ผศ.สุกัญญา     อ.ธรรณญพร                 60
# 79       wiggy-silver-drever   ดร.ธิปไตย      อ.ยุภาพร                 52
#
#      อาจารย์_y   กรรมการ 2  คะแนนกรรมการที่ 2  คะแนนกรรมการที่ 1 (30%)  \
# ...

# %%
All.columns
# Out:
# Index(['นักศึกษา', 'อาจารย์', 'กรรมการ 1', 'คะแนนกรรมการที่ 1', 'อาจารย์_y',
#        'กรรมการ 2', 'คะแนนกรรมการที่ 2', 'คะแนนกรรมการที่ 1 (30%)',
#        'คะแนนกรรมการที่ 2 (30%)', 'คะแนนรวม (60%)', 'รวม', 'คะแนน(40%)'],
#       dtype='object')

# %%
All = All[['นักศึกษา','อาจารย์', 'คะแนนรวม (60%)', 'คะแนน(40%)']]

# %%
All['คะแนนรวม'] = All['คะแนนรวม (60%)'] + All['คะแนน(40%)']
All
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                     นักศึกษา     อาจารย์  คะแนนรวม (60%)  คะแนน(40%)  \
# 0   boozy-thistle-wildebeest   ดร.ธนพงศ์       49.285714   36.571429
# 1          breezy-pear-macaw  ดร.อุทุมพร       48.000000   39.428571
# 2       bumpy-indigo-dolphin   ดร.ธิปไตย       45.857143   38.285714
# 3          chewy-lilac-shark   อ.ธรรณญพร       47.571429   34.857143
# 4    chewy-persimmon-catfish  รศ.สุพรรณี       40.714286   35.428571
# ..                       ...         ...             ...         ...
# 75    ugly-harlequin-octopus   รศ.วิชุดา       49.714286   32.857143
# ...

# %% [markdown]
# # 2.คะแนนรวมและเกรดที่ได้ของนักศึกษาแต่ละคน

# %% [markdown]
# * ถ้าคะแนนมากกว่าหรือเท่ากับ 80 ได้เกรด A
# * ถ้าคะแนนมากกว่าหรือเท่ากับ 75 แต่น้อยกว่า 80 จะได้เกรด B+
# * ถ้าคะแนนมากกว่าหรือเท่ากับ 70 แต่น้อยกว่า 75 จะได้เกรด B
# * ถ้าคะแนนมากกว่าหรือเท่ากับ 65 แต่น้อยกว่า 70 จะได้เกรด C+
# * ถ้าคะแนนมากกว่าหรือเท่ากับ 60 แต่น้อยกว่า 65 จะได้เกรด C
# * ถ้าคะแนนมากกว่าหรือเท่ากับ 55 แต่น้อยกว่า 60 จะได้เกรด D+
# * ถ้าคะแนนมากกว่าหรือเท่ากับ 50 แต่น้อยกว่า 55 จะได้เกรด D
# * ถ้าคะแนนน้อยกว่าหรือเท่ากับ 50 จะได้เกรด F

# %%
grades = {
    80: "A",
    75: "B+",
    70: "B",
    65: "C+",
    60: "C",
    55: "D+",
    50: "D",
    0: "F",
}

def grade_mapping(value):
    for key, letter in grades.items():
        if value >= key:
            return letter

# %%
letter_grades = All["คะแนนรวม"].map(grade_mapping)
All["เกรด"] = pd.Categorical(
    letter_grades, categories=grades.values(), ordered=True
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
All
# Out:
#                     นักศึกษา     อาจารย์  คะแนนรวม (60%)  คะแนน(40%)  \
# 0   boozy-thistle-wildebeest   ดร.ธนพงศ์       49.285714   36.571429
# 1          breezy-pear-macaw  ดร.อุทุมพร       48.000000   39.428571
# 2       bumpy-indigo-dolphin   ดร.ธิปไตย       45.857143   38.285714
# 3          chewy-lilac-shark   อ.ธรรณญพร       47.571429   34.857143
# 4    chewy-persimmon-catfish  รศ.สุพรรณี       40.714286   35.428571
# ..                       ...         ...             ...         ...
# 75    ugly-harlequin-octopus   รศ.วิชุดา       49.714286   32.857143
# 76        ugly-myrtle-walrus   อ.ธรรณญพร       40.714286   35.428571
# 77       whiny-peach-audemer    อ.ยุภาพร       41.571429   38.285714
# 78          whiny-pear-otter  ผศ.สุกัญญา       49.714286   36.000000
# 79       wiggy-silver-drever   ดร.ธิปไตย       42.857143   38.285714
#
#      คะแนนรวม เกรด
# 0   85.857143    A
# 1   87.428571    A
# 2   84.142857    A
# 3   82.428571    A
# 4   76.142857   B+
# ...

# %% [markdown]
# ## Save Table All

# %%
All.to_csv('Final.csv')

# %% [markdown]
# #3.วาดกราฟ
# - Stacked Barchart แสดงคะแนนรวมของนักศึกษาแต่ละคนโดยเรียงจากคะแนนรวมมากที่สุดไปน้อยที่สุด (คะแนนส่วนที่ปรึกษา ซ้อนกับ คะแนนสอบปากเปล่า)
# - Histogram แสดงจำนวนผู้ได้เกรดต่างๆ
# - Boxplot เปรียบเทียบการกระจายของคะแนนที่อ.กรรมการสอบปากเปล่าแต่ละท่านให้นักศึกษา

# %%
All.rename(columns={'คะแนนรวม (60%)' : 'คะแนนสอบปากเปล่า', 'คะแนน(40%)': 'คะแนนส่วนที่ปรึกษา'}, inplace = True)
All
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                     นักศึกษา     อาจารย์  คะแนนสอบปากเปล่า  \
# 0   boozy-thistle-wildebeest   ดร.ธนพงศ์         49.285714
# 1          breezy-pear-macaw  ดร.อุทุมพร         48.000000
# 2       bumpy-indigo-dolphin   ดร.ธิปไตย         45.857143
# 3          chewy-lilac-shark   อ.ธรรณญพร         47.571429
# 4    chewy-persimmon-catfish  รศ.สุพรรณี         40.714286
# ..                       ...         ...               ...
# 75    ugly-harlequin-octopus   รศ.วิชุดา         49.714286
# 76        ugly-myrtle-walrus   อ.ธรรณญพร         40.714286
# 77       whiny-peach-audemer    อ.ยุภาพร         41.571429
# 78          whiny-pear-otter  ผศ.สุกัญญา         49.714286
# ...

# %% [markdown]
# ### Stack bar

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(15,10))
x = All['นักศึกษา']
y1 = All['คะแนนสอบปากเปล่า']
y2 = All['คะแนนส่วนที่ปรึกษา']
plt.bar(x,y1, label='Oral test score', color ='SlateBlue')
plt.bar(x,y2,bottom=y1, label='Advisor score',color ='Coral')
plt.xticks(rotation = 90)
plt.legend()
plt.title('Stack bar')
# Out:
# Text(0.5, 1.0, 'Stack bar')

# %% [markdown]
# ###Histogram

# %%
figure(figsize=(10,5))
plt.title('Histogram : number of people in each grades')
All['คะแนนรวม'].hist(color='PowderBlue',grid=True)

# %% [markdown]
# ###Boxplot

# %%
committees = committee.dropna()
committees
# Out:
#                        นักศึกษา    อาจารย์  กรรมการสอบ  รวม
# 1          leaky-rust-chameleon  ดร.ธิปไตย  ผศ.วุฒิชัย   52
# 2            greasy-ruby-bombay  ดร.ธิปไตย  ผศ.วุฒิชัย   50
# 3          leaky-rust-chameleon  ดร.ธิปไตย    อ.ยุภาพร   60
# 4            greasy-ruby-bombay  ดร.ธิปไตย    อ.ยุภาพร   58
# 5           wiggy-silver-drever  ดร.ธิปไตย  ผศ.วุฒิชัย   52
# ..                          ...        ...         ...  ...
# 50         muggy-charcoal-akita   ดร.พลากร  ผศ.วุฒิชัย   52
# 51  stinky-wisteria-nightingale   ดร.พลากร   รศ.วิชุดา   57
# 52            hazy-aqua-peccary   ดร.พลากร   รศ.วิชุดา   57
# 53  stinky-wisteria-nightingale   ดร.พลากร   ดร.ธนพงศ์   59
# 54            hazy-aqua-peccary   ดร.พลากร   ดร.ธนพงศ์   59
#
# [160 rows x 4 columns]

# %%
a1 = committees[committees['กรรมการสอบ']=='ดร.ธิปไตย']
a2 = committees[committees['กรรมการสอบ']=='ดร.ธนพงศ์']
a3 = committees[committees['กรรมการสอบ']=='ดร.พลากร']
a4 = committees[committees['กรรมการสอบ']=='ดร.วรรณพร']
a5 = committees[committees['กรรมการสอบ']=='ดร.อุทุมพร']
a6 = committees[committees['กรรมการสอบ']=='ผศ.วุฒิชัย']
a7 = committees[committees['กรรมการสอบ']=='รศ.วิชุดา']
a8 = committees[committees['กรรมการสอบ']=='ผศ.สุกัญญา']
a9 = committees[committees['กรรมการสอบ']=='อ.ธรรณญพร']
a10 = committees[committees['กรรมการสอบ']=='อ.ยุภาพร']
a11 = committees[committees['กรรมการสอบ']=='รศ.ธิดาเดียว']
a12 = committees[committees['กรรมการสอบ']=='รศ.สุพรรณี']

# %%
figure(figsize=(20,10))
plt.subplot(2,6,1)
plt.boxplot(a1['รวม'], vert=False)
plt.title('DR. Tippatai')
plt.subplot(2,6,2)
plt.boxplot(a2['รวม'], vert=False)
plt.title('DR. Thanapong')
plt.subplot(2,6,3)
plt.boxplot(a3['รวม'], vert=False)
plt.title('DR. Palakorn')
plt.subplot(2,6,4)
plt.boxplot(a4['รวม'], vert=False)
plt.title('DR. Wannaporn')
plt.subplot(2,6,5)
plt.boxplot(a5['รวม'], vert=False)
plt.title('DR. Uthumporn')
plt.subplot(2,6,6)
plt.boxplot(a6['รวม'], vert=False)
plt.title('Assoc.Prof. Wuttichai')
plt.subplot(2,6,7)
plt.boxplot(a7['รวม'], vert=False)
plt.title('DR. Wichuda')
plt.subplot(2,6,8)
plt.boxplot(a8['รวม'], vert=False)
plt.title('Assoc.Prof. Sukanya')
plt.subplot(2,6,9)
plt.boxplot(a9['รวม'], vert=False)
plt.title('Prof. Tanyaporn')
plt.subplot(2,6,10)
plt.boxplot(a10['รวม'], vert=False)
plt.title('Prof. Yupaporn')
plt.subplot(2,6,11)
plt.boxplot(a11['รวม'], vert=False)
plt.title('Assoc.Prof. Thidadeaw')
plt.subplot(2,6,12)
plt.boxplot(a12['รวม'], vert=False)
plt.title('Assoc.Prof. Sukannee')
# Out:
# Text(0.5, 1.0, 'Assoc.Prof. Sukannee')
