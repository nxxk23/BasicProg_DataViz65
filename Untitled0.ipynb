# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/BasicProg_DataViz65/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounted Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##🔗[Drug Use Datasets](https://ourworldindata.org/drug-use)

# %% [markdown]
# ## 1 Deaths from substance use datasets

# %% [markdown]
#     - substances-risk-factor-vs-direct-deaths.csv
#     Deaths from substance use datasets

# %%
import pandas as pd
df1 = pd.read_csv('/content/drive/MyDrive/Project/substances-risk-factor-vs-direct-deaths.csv')
df1
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)  \
# 0                                                    93
# 1                                                   102
# 2                                                   118
# 3                                                   132
# 4                                                   142
# ...                                                 ...
# 6835                                                104
# 6836                                                110
# 6837                                                115
# ...

# %%
a=df1[df1['Year']==2019]
a
# Out:
#                               Entity Code  Year  \
# 29                       Afghanistan  AFG  2019
# 59              African Region (WHO)  NaN  2019
# 89                           Albania  ALB  2019
# 119                          Algeria  DZA  2019
# 149                   American Samoa  ASM  2019
# ...                              ...  ...   ...
# 6719  World Bank Lower Middle Income  NaN  2019
# 6749  World Bank Upper Middle Income  NaN  2019
# 6779                           Yemen  YEM  2019
# 6809                          Zambia  ZMB  2019
# 6839                        Zimbabwe  ZWE  2019
#
#       Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)  \
# 29                                                  406
# 59                                                 2703
# 89                                                   29
# 119                                                 526
# 149                                                   0
# ...

# %%
##เปลี่ยนชื่อ columns
a.rename(columns={'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)': 'Deaths - Drug', 'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)':'Deaths - Alcohol' , 'Deaths - Cause: All causes - Risk: Tobacco - Sex: Both - Age: All Ages (Number)': 'Deaths - Tobacco' , 'Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)':'Deaths - Drug Use', 'Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)':'Deaths - Alcohol use'}, inplace=True)
a
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                               Entity Code  Year  Deaths - Drug  \
# 29                       Afghanistan  AFG  2019            406
# 59              African Region (WHO)  NaN  2019           2703
# 89                           Albania  ALB  2019             29
# 119                          Algeria  DZA  2019            526
# 149                   American Samoa  ASM  2019              0
# ...                              ...  ...   ...            ...
# 6719  World Bank Lower Middle Income  NaN  2019          16585
# 6749  World Bank Upper Middle Income  NaN  2019          26734
# 6779                           Yemen  YEM  2019            261
# ...

# %%
a.dtypes
# Out:
# Entity                  object
# Code                    object
# Year                     int64
# Deaths - Drug            int64
# Deaths - Alcohol         int64
# Deaths - Tobacco         int64
# Deaths - Drug Use        int64
# Deaths - Alcohol use     int64
# dtype: object

# %%
a=a.drop('Code', axis=1)

# %%
a.isnull().any()
# Out:
# Entity                  False
# Year                    False
# Deaths - Drug           False
# Deaths - Alcohol        False
# Deaths - Tobacco        False
# Deaths - Drug Use       False
# Deaths - Alcohol use    False
# dtype: bool

# %% [markdown]
# ###a 228*7

# %%
a
# Out:
#                               Entity  Year  Deaths - Drug  Deaths - Alcohol  \
# 29                       Afghanistan  2019            406               147
# 59              African Region (WHO)  2019           2703              7261
# 89                           Albania  2019             29                18
# 119                          Algeria  2019            526               111
# 149                   American Samoa  2019              0                 1
# ...                              ...   ...            ...               ...
# 6719  World Bank Lower Middle Income  2019          16585             46164
# 6749  World Bank Upper Middle Income  2019          26734             73977
# 6779                           Yemen  2019            261                82
# 6809                          Zambia  2019             60               137
# 6839                        Zimbabwe  2019            127                53
#
# ...

# %% [markdown]
# ## 2 Number of deaths by risk factor

# %% [markdown]
#     - /content/drive/MyDrive/Project-number-of-deaths-by-risk-factor.csv
#     Number of deaths by risk factor, World, 2019 Datasets

# %%
import pandas as pd
df2 = pd.read_csv('/content/drive/MyDrive/Project/number-of-deaths-by-risk-factor.csv')
df2
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                                  3169
# 1                                                  3222
# 2                                                  3395
# 3                                                  3623
# 4                                                  3788
# ...                                                 ...
# 6835                                               2835
# 6836                                               2781
# ...

# %%
b=df2[df2['Year']==2019]
b
# Out:
#                               Entity Code  Year  \
# 29                       Afghanistan  AFG  2019
# 59              African Region (WHO)  NaN  2019
# 89                           Albania  ALB  2019
# 119                          Algeria  DZA  2019
# 149                   American Samoa  ASM  2019
# ...                              ...  ...   ...
# 6719  World Bank Lower Middle Income  NaN  2019
# 6749  World Bank Upper Middle Income  NaN  2019
# 6779                           Yemen  YEM  2019
# 6809                          Zambia  ZMB  2019
# 6839                        Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 29                                                 9154
# 59                                               245491
# 89                                                 1556
# 119                                               22229
# ...

# %%
b.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)',
# ...

# %%
##เปลี่ยนชื่อ columns
b.rename(columns={'Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)': 'Outdoor air pollution', 
                  'Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)': 'High systolic blood pressure',
                  'Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)': 'Diet high in sodium',
                  'Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)':'Diet low in whole grains',
                  'Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)':'Alcohol use',
                  'Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)':'Diet low in fruits',
                  'Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)':'Unsafe water source',
                  'Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)':'Secondhand smoke',
                  'Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)':'Low birth weight',
                  'Deaths - Cause: All causes - Risk: Child wasting - Sex: Both - Age: All Ages (Number)':'Child wasting',
                  'Deaths - Cause: All causes - Risk: Unsafe sex - Sex: Both - Age: All Ages (Number)':'Unsafe sex ',
                  'Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)':'Diet low in nuts and seeds',
                  'Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)':'Household air pollution from solid fuels',
                  'Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)':'Diet low in vegetables',
                  'Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)':'Low physical activity',
                  'Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: All Ages (Number)':'Smoking',
                  'Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)':'High fasting plasma glucose',
                  'Deaths - Cause: All causes - Risk: Air pollution - Sex: Both - Age: All Ages (Number)':'Air pollution',
                  'Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)':'High body-mass',
                  'Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)':'Unsafe sanitation',
                  'Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)':'No access to handwashing facility',
                  'Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)':'Drug use',
                  'Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)':'Low bone mineral density',
                  'Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)':'Vitamin A deficiency',
                  'Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)':'Child stunting',
                  'Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)':'Discontinued breastfeeding',
                  'Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)':'Non-exclusive breastfeeding',
                  'Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)':'Iron deficiency'}, inplace=True)
b
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                               Entity Code  Year  Outdoor air pollution  \
# 29                       Afghanistan  AFG  2019                   9154
# 59              African Region (WHO)  NaN  2019                 245491
# 89                           Albania  ALB  2019                   1556
# 119                          Algeria  DZA  2019                  22229
# 149                   American Samoa  ASM  2019                      8
# ...                              ...  ...   ...                    ...
# 6719  World Bank Lower Middle Income  NaN  2019                1971954
# 6749  World Bank Upper Middle Income  NaN  2019                2039121
# ...

# %%
b=b.drop('Code', axis=1)

# %%
b.isnull().any()
# Out:
# Entity                                      False
# Year                                        False
# Outdoor air pollution                       False
# High systolic blood pressure                False
# Diet high in sodium                         False
# Diet low in whole grains                    False
# Alcohol use                                 False
# Diet low in fruits                          False
# Unsafe water source                         False
# Secondhand smoke                            False
# Low birth weight                            False
# Child wasting                               False
# Unsafe sex                                  False
# Diet low in nuts and seeds                  False
# Household air pollution from solid fuels    False
# Diet low in vegetables                      False
# Low physical activity                       False
# Smoking                                     False
# High fasting plasma glucose                 False
# ...

# %% [markdown]
# ###b228*30

# %%
b
# Out:
#                               Entity  Year  Outdoor air pollution  \
# 29                       Afghanistan  2019                   9154
# 59              African Region (WHO)  2019                 245491
# 89                           Albania  2019                   1556
# 119                          Algeria  2019                  22229
# 149                   American Samoa  2019                      8
# ...                              ...   ...                    ...
# 6719  World Bank Lower Middle Income  2019                1971954
# 6749  World Bank Upper Middle Income  2019                2039121
# 6779                           Yemen  2019                  11598
# 6809                          Zambia  2019                   3048
# 6839                        Zimbabwe  2019                   2680
#
#       High systolic blood pressure  Diet high in sodium  \
# 29                           36017                 1422
# 59                          718299                71736
# ...

# %% [markdown]
# ##3 Number of deaths by cause, World, 2019

# %% [markdown]
#     -
#     Number of deaths by cause, World, 2019

# %%
df3=pd.read_csv('/content/drive/MyDrive/Project/annual-number-of-deaths-by-cause.csv')
df3
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 7268     Zimbabwe  ZWE  2015                                          NaN
# 7269     Zimbabwe  ZWE  2016                                          NaN
# 7270     Zimbabwe  ZWE  2017                                          NaN
# 7271     Zimbabwe  ZWE  2018                                          NaN
# 7272     Zimbabwe  ZWE  2019                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# ...

# %%
c=df3[df3['Year']==2019]
c
# Out:
#                               Entity Code  Year  \
# 29                       Afghanistan  AFG  2019
# 59              African Region (WHO)  NaN  2019
# 89                           Albania  ALB  2019
# 119                          Algeria  DZA  2019
# 149                   American Samoa  ASM  2019
# ...                              ...  ...   ...
# 7134  World Bank Lower Middle Income  NaN  2019
# 7164  World Bank Upper Middle Income  NaN  2019
# 7194                           Yemen  YEM  2019
# 7242                          Zambia  ZMB  2019
# 7272                        Zimbabwe  ZWE  2019
#
#      Number of executions (Amnesty International)  \
# 29                                            NaN
# 59                                            NaN
# 89                                            NaN
# 119                                           NaN
# 149                                           NaN
# ...                                           ...
# ...

# %%
c.isnull().any()
# Out:
# Entity                                                                                      False
# Code                                                                                         True
# Year                                                                                        False
# Number of executions (Amnesty International)                                                 True
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                    False
# Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)       False
# Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)                           False
# Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)                      False
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                       False
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                      False
# ...

# %%
#fillna with unknown value
c['Number of executions (Amnesty International)']  = c['Number of executions (Amnesty International)'].fillna('Unknown') 
c['Terrorism (deaths)'] = c['Terrorism (deaths)'].fillna('Unknown')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
c.isnull().any()
# Out:
# Entity                                                                                      False
# Code                                                                                         True
# Year                                                                                        False
# Number of executions (Amnesty International)                                                False
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                    False
# Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)       False
# Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)                           False
# Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)                      False
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                       False
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                      False
# ...

# %%
c.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Number of executions (Amnesty International)',
#        'Deaths - Meningitis - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Malaria - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Drowning - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)',
# ...

# %%
#เปลี่ยนชื่อ columns
c.rename(columns={'Deaths - Meningitis - Sex: Both - Age: All Ages (Number)':'Meningitis',
                  'Deaths - Alzheimers disease and other dementias - Sex: Both - Age: All Ages (Number)':'Alzheimers disease',
                  'Deaths - Parkinsons disease - Sex: Both - Age: All Ages (Number)':'Parkinson',
                  'Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)':'Nutritional deficiencies',
                  'Deaths - Malaria - Sex: Both - Age: All Ages (Number)':'Malaria',
                  'Deaths - Drowning - Sex: Both - Age: All Ages (Number)':'Drowning',
                  'Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)':'Interpersonal violence',
                  'Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)':'Maternal disorders',
                  'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)':'HIV/AIDS',
                  'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)':'Drug use disorders',
                  'Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)':'Tuberculosis',
                  'Deaths - Cardiovascular diseases - Sex: Both - Age: All Ages (Number)':'Cardiovascular diseases',
                  'Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)':'Lower respiratory infections',
                  'Deaths - Neonatal disorders - Sex: Both - Age: All Ages (Number)':'Neonatal disorders',
                  'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)':'Alcohol use disorders',
                  'Deaths - Self-harm - Sex: Both - Age: All Ages (Number)':'Self-harm',
                  'Deaths - Exposure to forces of nature - Sex: Both - Age: All Ages (Number)':'Exposure to forces of nature',
                  'Deaths - Diarrheal diseases - Sex: Both - Age: All Ages (Number)':'Diarrheal diseases',
                  'Deaths - Environmental heat and cold exposure - Sex: Both - Age: All Ages (Number)':'Environmental heat and cold exposure',
                  'Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)':'Neoplasms',
                  'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)':'Alcohol use disorders',
                  'Deaths - Diabetes mellitus - Sex: Both - Age: All Ages (Number)':'Diabetes mellitus',
                  'Deaths - Chronic kidney disease - Sex: Both - Age: All Ages (Number)':'Chronic kidney disease',
                  'Deaths - Poisonings - Sex: Both - Age: All Ages (Number)':'Poisonings',
                  'Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Number)':'Protein-energy malnutrition',
                  'Deaths - Road injuries - Sex: Both - Age: All Ages (Number)':'Road injuries',
                  'Deaths - Chronic respiratory diseases - Sex: Both - Age: All Ages (Number)':'Chronic respiratory diseases',
                  'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)':'Cirrhosis and other chronic liver diseases',
                  'Deaths - Digestive diseases - Sex: Both - Age: All Ages (Number)':'Digestive diseases',
                  'Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)':'Fire, heat, and hot substances',
                  'Deaths - Acute hepatitis - Sex: Both - Age: All Ages (Number)':'Acute hepatitis'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
c=c.drop('Code',axis=1)

# %%
c.isnull().any()
# Out:
# Entity                                                                                   False
# Year                                                                                     False
# Number of executions (Amnesty International)                                             False
# Meningitis                                                                               False
# Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)    False
# Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)                        False
# Nutritional deficiencies                                                                 False
# Malaria                                                                                  False
# Drowning                                                                                 False
# Interpersonal violence                                                                   False
# ...

# %% [markdown]
# ###c 228*35

# %%
c
# Out:
#                               Entity  Year  \
# 29                       Afghanistan  2019
# 59              African Region (WHO)  2019
# 89                           Albania  2019
# 119                          Algeria  2019
# 149                   American Samoa  2019
# ...                              ...   ...
# 7134  World Bank Lower Middle Income  2019
# 7164  World Bank Upper Middle Income  2019
# 7194                           Yemen  2019
# 7242                          Zambia  2019
# 7272                        Zimbabwe  2019
#
#      Number of executions (Amnesty International)  Meningitis  \
# 29                                        Unknown      1563.0
# 59                                        Unknown    139590.0
# 89                                        Unknown        13.0
# 119                                       Unknown       292.0
# 149                                       Unknown         1.0
# ...                                           ...         ...
# ...

# %% [markdown]
# ## 4 Share with alcohol or drug use disorders

# %% [markdown]
#     Alcohol and drug addiction is more common in men

# %%
df4 = pd.read_csv('/content/drive/MyDrive/Project/alcohol-or-drug-use-disorders-male-vs-female.csv')
df4
# Out:
#              Entity      Code  Year  \
# 0          Abkhazia  OWID_ABK  2015
# 1       Afghanistan       AFG  1990
# 2       Afghanistan       AFG  1991
# 3       Afghanistan       AFG  1992
# 4       Afghanistan       AFG  1993
# ...             ...       ...   ...
# 6916       Zimbabwe       ZWE  2016
# 6917       Zimbabwe       ZWE  2017
# 6918       Zimbabwe       ZWE  2018
# 6919       Zimbabwe       ZWE  2019
# 6920  Åland Islands       ALA  2015
#
#       Prevalence - Substance use disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                   NaN
# 1                                                  1.02
# 2                                                  1.01
# 3                                                  1.01
# 4                                                  1.00
# ...                                                 ...
# 6916                                               3.73
# ...

# %%
d = df4[df4['Year']==2019]
d
# Out:
#                               Entity Code  Year  \
# 30                       Afghanistan  AFG  2019
# 60              African Region (WHO)  NaN  2019
# 91                           Albania  ALB  2019
# 121                          Algeria  DZA  2019
# 151                   American Samoa  ASM  2019
# ...                              ...  ...   ...
# 6794  World Bank Lower Middle Income  NaN  2019
# 6824  World Bank Upper Middle Income  NaN  2019
# 6855                           Yemen  YEM  2019
# 6888                          Zambia  ZMB  2019
# 6919                        Zimbabwe  ZWE  2019
#
#       Prevalence - Substance use disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 30                                                 1.02
# 60                                                 2.17
# 91                                                 2.45
# 121                                                1.16
# 151                                                1.88
# ...

# %%
d=d.drop('Code',axis=1)
d=d.drop('Continent',axis=1)

# %%
d.isnull().any()
# Out:
# Entity                                                                                  False
# Year                                                                                    False
# Prevalence - Substance use disorders - Sex: Male - Age: Age-standardized (Percent)      False
# Prevalence - Substance use disorders - Sex: Female - Age: Age-standardized (Percent)    False
# dtype: bool

# %% [markdown]
# ###d 228*4

# %%
d
# Out:
#                               Entity  Year  \
# 30                       Afghanistan  2019
# 60              African Region (WHO)  2019
# 91                           Albania  2019
# 121                          Algeria  2019
# 151                   American Samoa  2019
# ...                              ...   ...
# 6794  World Bank Lower Middle Income  2019
# 6824  World Bank Upper Middle Income  2019
# 6855                           Yemen  2019
# 6888                          Zambia  2019
# 6919                        Zimbabwe  2019
#
#       Prevalence - Substance use disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 30                                                 1.02
# 60                                                 2.17
# 91                                                 2.45
# 121                                                1.16
# 151                                                1.88
# ...                                                 ...
# ...

# %% [markdown]
# #5 Alcohol use vs. drug use disorders

# %%
df5 = pd.read_csv('/content/drive/MyDrive/Project/share-with-alcohol-vs-drug-use-disorder.csv')
df5
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 57645       Zimbabwe       ZWE  1988
# 57646       Zimbabwe       ZWE  1989
# 57647       Zimbabwe       ZWE  2020
# 57648       Zimbabwe       ZWE  2021
# 57649  Åland Islands       ALA  2015
#
#        Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                                   0.44
# 2                                                   0.44
# 3                                                   0.45
# 4                                                   0.45
# ...                                                  ...
# 57645                                                NaN
# ...

# %%
e = df5[df5['Year']==2019]
e
# Out:
#                                Entity Code  Year  \
# 30                        Afghanistan  AFG  2019
# 516                            Africa  NaN  2019
# 548              African Region (WHO)  NaN  2019
# 579                           Albania  ALB  2019
# 838                           Algeria  DZA  2019
# ...                               ...  ...   ...
# 56836  World Bank Lower Middle Income  NaN  2019
# 56866  World Bank Upper Middle Income  NaN  2019
# 56897                           Yemen  YEM  2019
# 57159                          Zambia  ZMB  2019
# 57419                        Zimbabwe  ZWE  2019
#
#        Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 30                                                  0.44
# 516                                                  NaN
# 548                                                 1.11
# 579                                                 1.79
# ...

# %%
e['Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)'] = e['Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)'].fillna('-')
e['Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)'] = e['Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)'].fillna('-')
e['Population (historical estimates)'] = e['Population (historical estimates)'].fillna('-')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
e = e.drop('Continent', axis=1)
e = e.drop('Code',axis=1)

# %%
e.isnull().any()
# Out:
# Entity                                                                              False
# Year                                                                                False
# Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)    False
# Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)       False
# Population (historical estimates)                                                   False
# dtype: bool

# %% [markdown]
# ###e 271*5

# %%
e
# Out:
#                                Entity  Year  \
# 30                        Afghanistan  2019
# 516                            Africa  2019
# 548              African Region (WHO)  2019
# 579                           Albania  2019
# 838                           Algeria  2019
# ...                               ...   ...
# 56836  World Bank Lower Middle Income  2019
# 56866  World Bank Upper Middle Income  2019
# 56897                           Yemen  2019
# 57159                          Zambia  2019
# 57419                        Zimbabwe  2019
#
#       Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 30                                                  0.44
# 516                                                    -
# 548                                                 1.11
# 579                                                 1.79
# 838                                                 0.43
# ...

# %% [markdown]
# # 6 Deaths from substance use disorders

# %%
df6 = pd.read_csv('/content/drive/MyDrive/Project/deaths-substance-disorders.csv')
df6
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cocaine use disorders - Sex: Both - Age: All Ages (Number)  \
# 0                                                     3
# 1                                                     3
# 2                                                     4
# 3                                                     4
# 4                                                     4
# ...                                                 ...
# 6835                                                 10
# 6836                                                 11
# 6837                                                 12
# ...

# %%
f = df6[df6['Year']==2019]

# %%
f.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Cocaine use disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Opioid use disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Other drug use disorders - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Amphetamine use disorders - Sex: Both - Age: All Ages (Number)'],
#       dtype='object')

# %%
##เปลี่ยนชื่อ columns
f.rename(columns={'Deaths - Cocaine use disorders - Sex: Both - Age: All Ages (Number)':'Cocaine',
                  'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)':'Drug',
                  'Deaths - Opioid use disorders - Sex: Both - Age: All Ages (Number)':'Opioid',
                  'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)':'Alcohol',
                  'Deaths - Other drug use disorders - Sex: Both - Age: All Ages (Number)':'Other drug',
                  'Deaths - Amphetamine use disorders - Sex: Both - Age: All Ages (Number)':'Amphetamine'}, inplace=True)
f
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                               Entity Code  Year  Cocaine   Drug  Opioid  \
# 29                       Afghanistan  AFG  2019       16    406     313
# 59              African Region (WHO)  NaN  2019      132   2703    1983
# 89                           Albania  ALB  2019        1     29      23
# 119                          Algeria  DZA  2019       31    526     365
# 149                   American Samoa  ASM  2019        0      0       0
# ...                              ...  ...   ...      ...    ...     ...
# 6719  World Bank Lower Middle Income  NaN  2019     1066  16585   11610
# 6749  World Bank Upper Middle Income  NaN  2019     2311  26734   16032
# ...

# %%
f = f.drop('Code',axis=1)

# %%
f.isnull().any()
# Out:
# Entity         False
# Year           False
# Cocaine        False
# Drug           False
# Opioid         False
# Alcohol        False
# Other drug     False
# Amphetamine    False
# dtype: bool

# %% [markdown]
# ###f 228*8

# %%
f
# Out:
#                               Entity  Year  Cocaine   Drug  Opioid  Alcohol  \
# 29                       Afghanistan  2019       16    406     313      147
# 59              African Region (WHO)  2019      132   2703    1983     7261
# 89                           Albania  2019        1     29      23       18
# 119                          Algeria  2019       31    526     365      111
# 149                   American Samoa  2019        0      0       0        1
# ...                              ...   ...      ...    ...     ...      ...
# 6719  World Bank Lower Middle Income  2019     1066  16585   11610    46164
# 6749  World Bank Upper Middle Income  2019     2311  26734   16032    73977
# 6779                           Yemen  2019       12    261     194       82
# 6809                          Zambia  2019        4     60      38      137
# 6839                        Zimbabwe  2019       14    127      92       53
#
#       Other drug  Amphetamine
# ...

# %% [markdown]
# #🔗Merge tables

# %%
a.columns
# Out:
# Index(['Entity', 'Year', 'Deaths - Drug', 'Deaths - Alcohol',
#        'Deaths - Tobacco', 'Deaths - Drug Use', 'Deaths - Alcohol use'],
#       dtype='object')

# %%
b.columns
# Out:
# Index(['Entity', 'Year', 'Outdoor air pollution',
#        'High systolic blood pressure', 'Diet high in sodium',
#        'Diet low in whole grains', 'Alcohol use', 'Diet low in fruits',
#        'Unsafe water source', 'Secondhand smoke', 'Low birth weight',
#        'Child wasting', 'Unsafe sex ', 'Diet low in nuts and seeds',
#        'Household air pollution from solid fuels', 'Diet low in vegetables',
#        'Low physical activity', 'Smoking', 'High fasting plasma glucose',
#        'Air pollution', 'High body-mass', 'Unsafe sanitation',
#        'No access to handwashing facility', 'Drug use',
#        'Low bone mineral density', 'Vitamin A deficiency', 'Child stunting',
#        'Discontinued breastfeeding', 'Non-exclusive breastfeeding',
#        'Iron deficiency'],
#       dtype='object')

# %%
# select columns 
b = b[['Entity', 'Outdoor air pollution',
       'High systolic blood pressure', 'Diet high in sodium',
       'Diet low in whole grains', 'Alcohol use', 'Diet low in fruits',
       'Unsafe water source', 'Secondhand smoke', 'Low birth weight',
       'Child wasting', 'Unsafe sex ', 'Diet low in nuts and seeds',
       'Household air pollution from solid fuels',
       'Diet low in vegetables', 'Low physical activity', 'Smoking',
       'High fasting plasma glucose', 'Air pollution', 'High body-mass',
       'Unsafe sanitation', 'No access to handwashing facility', 'Drug use',
       'Low bone mineral density', 'Vitamin A deficiency', 'Child stunting',
       'Discontinued breastfeeding', 'Non-exclusive breastfeeding',
       'Iron deficiency']]

# %%
m1 = a.merge(b, how='left', right_on = 'Entity', left_on = 'Entity')
m1
# Out:
#                              Entity  Year  Deaths - Drug  Deaths - Alcohol  \
# 0                       Afghanistan  2019            406               147
# 1              African Region (WHO)  2019           2703              7261
# 2                           Albania  2019             29                18
# 3                           Algeria  2019            526               111
# 4                    American Samoa  2019              0                 1
# ..                              ...   ...            ...               ...
# 223  World Bank Lower Middle Income  2019          16585             46164
# 224  World Bank Upper Middle Income  2019          26734             73977
# 225                           Yemen  2019            261                82
# 226                          Zambia  2019             60               137
# 227                        Zimbabwe  2019            127                53
#
#      Deaths - Tobacco  Deaths - Drug Use  Deaths - Alcohol use  \
# ...

# %%
c.columns
# Out:
# Index(['Entity', 'Year', 'Number of executions (Amnesty International)',
#        'Meningitis',
#        'Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)',
#        'Nutritional deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal violence', 'Maternal disorders', 'HIV/AIDS',
#        'Drug use disorders', 'Tuberculosis', 'Cardiovascular diseases',
#        'Lower respiratory infections', 'Neonatal disorders',
#        'Alcohol use disorders', 'Self-harm', 'Exposure to forces of nature',
#        'Diarrheal diseases', 'Environmental heat and cold exposure',
#        'Neoplasms',
#        'Deaths - Conflict and terrorism - Sex: Both - Age: All Ages (Number)',
#        'Diabetes mellitus', 'Chronic kidney disease', 'Poisonings',
#        'Protein-energy malnutrition', 'Terrorism (deaths)', 'Road injuries',
#        'Chronic respiratory diseases',
# ...

# %%
d.columns
# Out:
# Index(['Entity', 'Year',
#        'Prevalence - Substance use disorders - Sex: Male - Age: Age-standardized (Percent)',
#        'Prevalence - Substance use disorders - Sex: Female - Age: Age-standardized (Percent)'],
#       dtype='object')

# %%
d = d[['Entity',
       'Prevalence - Substance use disorders - Sex: Male - Age: Age-standardized (Percent)',
       'Prevalence - Substance use disorders - Sex: Female - Age: Age-standardized (Percent)']]

# %%
m2 = c.merge(d, how='left', right_on = 'Entity', left_on = 'Entity')
m2
# Out:
#                              Entity  Year  \
# 0                       Afghanistan  2019
# 1              African Region (WHO)  2019
# 2                           Albania  2019
# 3                           Algeria  2019
# 4                    American Samoa  2019
# ..                              ...   ...
# 223  World Bank Lower Middle Income  2019
# 224  World Bank Upper Middle Income  2019
# 225                           Yemen  2019
# 226                          Zambia  2019
# 227                        Zimbabwe  2019
#
#     Number of executions (Amnesty International)  Meningitis  \
# 0                                        Unknown      1563.0
# 1                                        Unknown    139590.0
# 2                                        Unknown        13.0
# 3                                        Unknown       292.0
# 4                                        Unknown         1.0
# ..                                           ...         ...
# ...

# %%
m1.columns
# Out:
# Index(['Entity', 'Year', 'Deaths - Drug', 'Deaths - Alcohol',
#        'Deaths - Tobacco', 'Deaths - Drug Use', 'Deaths - Alcohol use',
#        'Outdoor air pollution', 'High systolic blood pressure',
#        'Diet high in sodium', 'Diet low in whole grains', 'Alcohol use',
#        'Diet low in fruits', 'Unsafe water source', 'Secondhand smoke',
#        'Low birth weight', 'Child wasting', 'Unsafe sex ',
#        'Diet low in nuts and seeds',
#        'Household air pollution from solid fuels', 'Diet low in vegetables',
#        'Low physical activity', 'Smoking', 'High fasting plasma glucose',
#        'Air pollution', 'High body-mass', 'Unsafe sanitation',
#        'No access to handwashing facility', 'Drug use',
#        'Low bone mineral density', 'Vitamin A deficiency', 'Child stunting',
#        'Discontinued breastfeeding', 'Non-exclusive breastfeeding',
#        'Iron deficiency'],
#       dtype='object')

# %%
m2.columns
# Out:
# Index(['Entity', 'Year', 'Number of executions (Amnesty International)',
#        'Meningitis',
#        'Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)',
#        'Nutritional deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal violence', 'Maternal disorders', 'HIV/AIDS',
#        'Drug use disorders', 'Tuberculosis', 'Cardiovascular diseases',
#        'Lower respiratory infections', 'Neonatal disorders',
#        'Alcohol use disorders', 'Self-harm', 'Exposure to forces of nature',
#        'Diarrheal diseases', 'Environmental heat and cold exposure',
#        'Neoplasms',
#        'Deaths - Conflict and terrorism - Sex: Both - Age: All Ages (Number)',
#        'Diabetes mellitus', 'Chronic kidney disease', 'Poisonings',
#        'Protein-energy malnutrition', 'Terrorism (deaths)', 'Road injuries',
#        'Chronic respiratory diseases',
# ...

# %%
##select all column w/o year
m1=m1[['Entity', 'Deaths - Drug', 'Deaths - Alcohol',
       'Deaths - Tobacco', 'Deaths - Drug Use', 'Deaths - Alcohol use',
       'Outdoor air pollution', 'High systolic blood pressure',
       'Diet high in sodium', 'Diet low in whole grains', 'Alcohol use',
       'Diet low in fruits', 'Unsafe water source', 'Secondhand smoke',
       'Low birth weight', 'Child wasting', 'Unsafe sex ',
       'Diet low in nuts and seeds',
       'Household air pollution from solid fuels', 'Diet low in vegetables',
       'Low physical activity', 'Smoking', 'High fasting plasma glucose',
       'Air pollution', 'High body-mass', 'Unsafe sanitation',
       'No access to handwashing facility', 'Drug use',
       'Low bone mineral density', 'Vitamin A deficiency', 'Child stunting',
       'Discontinued breastfeeding', 'Non-exclusive breastfeeding',
       'Iron deficiency']]

# %%
m3 = m1.merge(m2, how='left', right_on = 'Entity', left_on = 'Entity')
m3
# Out:
#                              Entity  Deaths - Drug  Deaths - Alcohol  \
# 0                       Afghanistan            406               147
# 1              African Region (WHO)           2703              7261
# 2                           Albania             29                18
# 3                           Algeria            526               111
# 4                    American Samoa              0                 1
# ..                              ...            ...               ...
# 223  World Bank Lower Middle Income          16585             46164
# 224  World Bank Upper Middle Income          26734             73977
# 225                           Yemen            261                82
# 226                          Zambia             60               137
# 227                        Zimbabwe            127                53
#
#      Deaths - Tobacco  Deaths - Drug Use  Deaths - Alcohol use  \
# 0               15799                700                   583
# ...

# %%
f.columns
# Out:
# Index(['Entity', 'Year', 'Cocaine', 'Drug', 'Opioid', 'Alcohol', 'Other drug',
#        'Amphetamine'],
#       dtype='object')

# %%
f=f[['Entity', 'Cocaine', 'Drug', 'Opioid', 'Alcohol','Other drug', 'Amphetamine']]

# %%
m4 = m3.merge(f, how='left', right_on = 'Entity', left_on = 'Entity')
m4
# Out:
#                              Entity  Deaths - Drug  Deaths - Alcohol  \
# 0                       Afghanistan            406               147
# 1              African Region (WHO)           2703              7261
# 2                           Albania             29                18
# 3                           Algeria            526               111
# 4                    American Samoa              0                 1
# ..                              ...            ...               ...
# 223  World Bank Lower Middle Income          16585             46164
# 224  World Bank Upper Middle Income          26734             73977
# 225                           Yemen            261                82
# 226                          Zambia             60               137
# 227                        Zimbabwe            127                53
#
#      Deaths - Tobacco  Deaths - Drug Use  Deaths - Alcohol use  \
# 0               15799                700                   583
# ...

# %%
e.columns
# Out:
# Index(['Entity', 'Year',
#        'Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Population (historical estimates)'],
#       dtype='object')

# %%
e=e[['Entity',
       'Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)',
       'Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)',
       'Population (historical estimates)']]

# %%
m5 = m4.merge(e, how='left', right_on = 'Entity', left_on = 'Entity')
m5
# Out:
#                              Entity  Deaths - Drug  Deaths - Alcohol  \
# 0                       Afghanistan            406               147
# 1              African Region (WHO)           2703              7261
# 2                           Albania             29                18
# 3                           Algeria            526               111
# 4                    American Samoa              0                 1
# ..                              ...            ...               ...
# 223  World Bank Lower Middle Income          16585             46164
# 224  World Bank Upper Middle Income          26734             73977
# 225                           Yemen            261                82
# 226                          Zambia             60               137
# 227                        Zimbabwe            127                53
#
#      Deaths - Tobacco  Deaths - Drug Use  Deaths - Alcohol use  \
# 0               15799                700                   583
# ...

# %%
m5.isnull()
# Out:
#      Entity  Deaths - Drug  Deaths - Alcohol  Deaths - Tobacco  \
# 0     False          False             False             False
# 1     False          False             False             False
# 2     False          False             False             False
# 3     False          False             False             False
# 4     False          False             False             False
# ..      ...            ...               ...               ...
# 223   False          False             False             False
# 224   False          False             False             False
# 225   False          False             False             False
# 226   False          False             False             False
# 227   False          False             False             False
#
#      Deaths - Drug Use  Deaths - Alcohol use  Outdoor air pollution  \
# 0                False                 False                  False
# 1                False                 False                  False
# ...

# %%
m5.to_csv('final.csv')
