# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/BasicProg_DataViz65/blob/main/DataViz02_Data_Distribution_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Scatter Plot

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter([1,-1],[2,-1])

# %%
plt.scatter(df['PetalLength'],df['SepalLength'])

# %% [markdown]
# ## เปลี่ยนสี

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='r')

# %% [markdown]
# ## ระบุสีให้แต่ละจุด

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# ### แทนค่าชื่อดอกไม้ด้วยตัวอักษรแทนสี (r g b c m y k w)

# %%
df2 = df.replace({'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'})

# %%
df2.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0          5.1         3.5          1.4         0.2    r
# 1          4.9         3.0          1.4         0.2    r
# 2          4.7         3.2          1.3         0.2    r
# 3          4.6         3.1          1.5         0.2    r
# 4          5.0         3.6          1.4         0.2    r

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])

# %%
plt.scatter(df2['SepalLength'],df2['SepalWidth'],c=df2['Name'])

# %% [markdown]
# ## เพิ่มรายละเอียดกราฟ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อ marker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('Comparing petal & sepal length of different iris flowers');

# %% [markdown]
# ## ใช้ ขนาดของ marker ในการแสดงค่าใน column

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ขยายของขนาด marker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ## ปรับความโปรงใสของ marker เพื่อให้มองเห็นจุดที่ถูกบัง (Bubble Chart)

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers \n(sizes of the circle determine petal widths of the flowers)');

# %% [markdown]
# ## เปลี่ยน หน้าตาของ Marker เพื่อความสวยงาม

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='X')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='X')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='X')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='$s$')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='$c$')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='$g$')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ## แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],df2['SepalWidth'],c=df2['Name'],s=80*df2['PetalWidth'])

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='setosa')
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],df2['SepalWidth'][50:100],c=df2['Name'][50:100],s=80*df2['PetalWidth'][50:100],label='versicolor')
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s=80*df2['PetalWidth'][100:],label='verginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ### จบ 26 Sep 2022

# %% [markdown]
# # Boxplot

# %% [markdown]
# ![1*2c21SkzJMf3frPXPAR_gZA-2.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df['SepalLength']);

# %%
plt.boxplot(df['SepalLength'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1e6ede0e50>,
#   <matplotlib.lines.Line2D at 0x7f1e6ee103d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1e6ee10910>,
#   <matplotlib.lines.Line2D at 0x7f1e6ee10e50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1e6ee57490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1e6ee18410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1e6ee18950>],
#  'means': []}

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False)

# %%
ybp
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1e6eddf810>,
#   <matplotlib.lines.Line2D at 0x7f1e70793190>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1e70717790>,
#   <matplotlib.lines.Line2D at 0x7f1e706d6690>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1e6edc52d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1e706d6390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1e70726190>],
#  'means': []}

# %% [markdown]
# median

# %%
ybp['medians']

# %%
ybp['medians'][0]

# %%
ybp['medians'][0].get_xdata()[0]  #median
# Out:
# 5.8

# %%
ybp['medians'][0].get_ydata()
# Out:
# array([0.925, 1.075])

# %%
ybp['whiskers']
# Out:
# [<matplotlib.lines.Line2D at 0x7f1e6eddf810>,
#  <matplotlib.lines.Line2D at 0x7f1e70793190>]

# %%
ybp['whiskers'][0].get_xdata()
# Out:
# array([5.1, 4.3])

# %%
min(ybp['whiskers'][0].get_xdata())   # min
# Out:
# 4.3

# %%
max(ybp['whiskers'][1].get_xdata())   # max
# Out:
# 7.9

# %%
ybp['caps'][1].get_xdata()
# Out:
# array([7.9, 7.9])

# %% [markdown]
# q1

# %%
ybp['boxes']

# %%
ybp['boxes'][0].get_xdata()
# Out:
# array([5.1, 5.1, 6.4, 6.4, 5.1])

# %%
ybp['boxes'][0].get_xdata()[0]
# Out:
# 5.1

# %% [markdown]
# outlier

# %%
ybp['fliers']

# %%
ybp['fliers'][0].get_xdata()
# Out:
# array([], dtype=float64)

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1e72fa5dd0>,
#   <matplotlib.lines.Line2D at 0x7f1e72ff8690>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1e72ff85d0>,
#   <matplotlib.lines.Line2D at 0x7f1e72ff8910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1e6ee49550>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1e7300b8d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1e730ba810>],
#  'means': [<matplotlib.lines.Line2D at 0x7f1e7300b290>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline=True,showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1e73108210>,
#   <matplotlib.lines.Line2D at 0x7f1e73108d50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1e73187b90>,
#   <matplotlib.lines.Line2D at 0x7f1e731871d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1e730e0390>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1e73187390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1e731c7410>],
#  'means': [<matplotlib.lines.Line2D at 0x7f1e731c7110>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanprops={'marker':'o'})
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1e7325d390>,
#   <matplotlib.lines.Line2D at 0x7f1e7325d590>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1e7325d810>,
#   <matplotlib.lines.Line2D at 0x7f1e732b6d10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1e731ec650>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1e732b6190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1e73c171d0>],
#  'means': [<matplotlib.lines.Line2D at 0x7f1e73c173d0>]}

# %% [markdown]
# # ตัวอย่าง Quiz กลุ่ม final
#
# 1. เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3
# 2. วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %%
bb = plt.boxplot(df['SepalLength'])

# %%
def detail_boxreturn(boxreturn):
    q1 = boxreturn['boxes'][0].get_ydata()[0]
    q2 = boxreturn['medians'][0].get_ydata()[0]
    q3 = boxreturn['boxes'][0].get_ydata()[2]
    minv = min(boxreturn['whiskers'][0].get_ydata())
    maxv = max(boxreturn['whiskers'][1].get_ydata())
    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn(bb)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
bb2 = plt.boxplot(df['SepalLength'],vert=False)

# %%
detail_boxreturn(bb2)
# Out:
# min = 1.0, max = 1.0, q1 = 0.925, q2 = 0.925, q3 = 1.075

# %%
def detail_boxreturn_v2(boxreturn, vert=True):
    if vert == True:
        q1 = boxreturn['boxes'][0].get_ydata()[0]
        q2 = boxreturn['medians'][0].get_ydata()[0]
        q3 = boxreturn['boxes'][0].get_ydata()[2]
        minv = min(boxreturn['whiskers'][0].get_ydata())
        maxv = max(boxreturn['whiskers'][1].get_ydata())     
    else: #vert == False
        q1 = boxreturn['boxes'][0].get_xdata()[0]
        q2 = boxreturn['medians'][0].get_xdata()[0]
        q3 = boxreturn['boxes'][0].get_xdata()[2]
        minv = min(boxreturn['whiskers'][0].get_xdata())
        maxv = max(boxreturn['whiskers'][1].get_xdata())   

    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn_v2(bb2)
# Out:
# min = 1.0, max = 1.0, q1 = 0.925, q2 = 0.925, q3 = 1.075

# %%
detail_boxreturn_v2(bb2,vert=False)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
plt.boxplot(df['PetalLength'][:50],positions = [1] )
plt.boxplot(df['PetalLength'][50:100],positions = [2] )
plt.boxplot(df['PetalLength'][100:150],positions = [3] );

# %% [markdown]
# # Violin plot

# %%
bb = plt.boxplot(df['PetalLength'][:50])

# %%
plt.violinplot(df['PetalLength'][:50])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f1e6ed1e050>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f1e6ed92dd0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f1e6ed1e210>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f1e7300b210>}

# %%
plt.subplot(1,2,1)
bb = plt.boxplot(df['PetalLength'][:50])
q1 = bb['boxes'][0].get_ydata()[0]
q2 = bb['medians'][0].get_ydata()[0]
q3 = bb['boxes'][0].get_ydata()[2]
plt.subplot(1,2,2)
vi = plt.violinplot(df['PetalLength'][:50],showmedians=True)

# %% [markdown]
# # quiz 6
# ให้เปรียบเทียบการกระจายตัวของราคาบ้านเดี่ยวและคอนโด ระหว่างจังหวัด กทม ขอนแก่น และเชียงใหม่ (ด้วย boxplot)
# ![quiz7.jpg](data:image/jpeg;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_project.csv')

# %%
unit = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_unittype.csv')

# %%
data1 = unit.merge(project, left_on='project_id', right_on='project_id')
data1
# Out:
#        row_number_x               unittype_id                project_id  \
# 0             27501             unittype_9565              project_2446
# 1             38108            unittype_18502              project_2446
# 2              2396             unittype_9564              project_2446
# 3             28777            unittype_10267              project_3543
# 4             28777            unittype_10267              project_3543
# ...             ...                       ...                       ...
# 53724         33124            unittype_21700              project_8631
# 53725         11293            unittype_32960             project_14046
# 53726         41022  617fc61e551dd10015a6933e  617fc4d3f62011001350de55
# 53727         35109             unittype_1459               project_711
# 53728          9333            unittype_37375             project_16389
#
#                  name_th_x  propertytype_id_x propertytype_name_en_x  \
# 0                2 Bedroom                  2                  Condo
# 1                1 Bedroom                  2                  Condo
# 2           1 Bedroom Plus                  2                  Condo
# 3       บ้านแฝดสองชั้น Z-2              20000             Twin house
# 4       บ้านแฝดสองชั้น Z-2              20000             Twin house
# ...                    ...                ...                    ...
# 53724  อาคารพาณิชย์สามชั้น                  4             Commercial
# 53725    บ้านเดี่ยวสองชั้น                  1         Detached House
# 53726      ทาวน์โฮมสามชั้น                  3               Townhome
# 53727          บ้านแสงรุ่ง                  3               Townhome
# 53728  บ้านเดี่ยวชั้นเดียว                  1         Detached House
#
#       propertytype_name_th_x  area_total_min_wa  area_usable_min  price_min_x  \
# 0                      คอนโด                NaN             37.3    2500000.0
# 1                      คอนโด                NaN             24.0    1390000.0
# 2                      คอนโด                NaN             29.0    1990000.0
# 3                    บ้านแฝด               40.0            150.0    2390000.0
# 4                    บ้านแฝด               40.0            150.0    2390000.0
# ...                      ...                ...              ...          ...
# 53724           อาคารพาณิชย์                NaN            250.0    5990000.0
# 53725                   บ้าน                NaN              NaN          NaN
# 53726               ทาวน์โฮม                NaN            142.1    4880000.0
# 53727               ทาวน์โฮม                NaN              NaN          NaN
# 53728                   บ้าน                NaN            180.0    3200000.0
#
#        ...  facility_meeting  facility_park  facility_playground  \
# 0      ...               NaN            1.0                  NaN
# 1      ...               NaN            1.0                  NaN
# 2      ...               NaN            1.0                  NaN
# 3      ...               NaN            NaN                  NaN
# 4      ...               NaN            NaN                  NaN
# ...    ...               ...            ...                  ...
# 53724  ...               NaN            NaN                  NaN
# 53725  ...               0.0            0.0                  0.0
# 53726  ...               NaN            1.0                  NaN
# 53727  ...               NaN            NaN                  NaN
# 53728  ...               NaN            NaN                  NaN
#
#        facility_pool  facility_security       date_created_y  \
# 0                1.0                1.0  2016-11-10 16:56:40
# 1                1.0                1.0  2016-11-10 16:56:40
# 2                1.0                1.0  2016-11-10 16:56:40
# 3                NaN                NaN  2017-01-24 13:55:45
# 4                NaN                NaN  2017-01-24 13:55:45
# ...              ...                ...                  ...
# 53724            NaN                NaN  2017-07-11 15:26:09
# 53725            0.0                0.0  2018-07-02 09:22:58
# 53726            1.0                1.0  2021-11-01 17:43:31
# 53727            NaN                NaN  2015-10-27 14:23:04
# 53728            NaN                NaN  2019-07-12 15:47:44
#
#                date_finish       date_updated_y  source_y  \
# 0      2018-01-01 07:00:00  2021-11-19 18:00:09    baania
# 1      2018-01-01 07:00:00  2021-11-19 18:00:09    baania
# 2      2018-01-01 07:00:00  2021-11-19 18:00:09    baania
# 3      2022-01-01 07:00:00  2022-01-27 14:30:04    baania
# 4      2022-01-01 07:00:00  2022-01-27 14:30:04    baania
# ...                    ...                  ...       ...
# 53724  1970-01-02 07:00:00  2020-12-04 10:46:14    baania
# 53725  2015-12-31 07:00:00  2020-12-04 10:44:59    baania
# 53726                  NaN  2021-11-02 10:30:03    baania
# 53727  1970-01-02 07:00:00  2020-12-04 10:36:46    baania
# 53728  1970-01-02 07:00:00  2020-12-04 10:42:26    baania
#
#                                              url_project
# 0      https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...
# 1      https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...
# 2      https://baania.com/th/project/เฟ-ลิค-คอนโด-ลาด...
# 3      https://baania.com/th/project/เซน-บาย-ศิวาลัย-...
# 4      https://baania.com/th/project/เซน-บาย-ศิวาลัย-...
# ...                                                  ...
# 53724  https://baania.com/th/project/พลอยไพลิน-เพลส-p...
# 53725  https://baania.com/th/project/เดอะ-ซันไรซ์-โอเ...
# 53726  https://baania.com/th/project/บ้านกลางเมือง-สุ...
# 53727  https://baania.com/th/project/บ้านแสงรุ่ง-proj...
# 53728  https://baania.com/th/project/ณรงค์กิจ-รามอินท...
#
# [53729 rows x 71 columns]

# %%
data = data1[['province_name_en','propertytype_name_en_x','price_min_x']]
data
# Out:
#       province_name_en propertytype_name_en_x  price_min_x
# 0              Bangkok                  Condo    2500000.0
# 1              Bangkok                  Condo    1390000.0
# 2              Bangkok                  Condo    1990000.0
# 3           Chiang Mai             Twin house    2390000.0
# 4           Chiang Mai             Twin house    2390000.0
# ...                ...                    ...          ...
# 53724          Bangkok             Commercial    5990000.0
# 53725           Phuket         Detached House          NaN
# 53726          Bangkok               Townhome    4880000.0
# 53727       Chiang Mai               Townhome          NaN
# 53728          Bangkok         Detached House    3200000.0
#
# [53729 rows x 3 columns]

# %%
data.isnull().any()
# Out:
# province_name_en           True
# propertytype_name_en_x    False
# price_min_x                True
# dtype: bool

# %%
dataa= data.dropna()

# %%
dataa.isnull().any()
# Out:
# province_name_en          False
# propertytype_name_en_x    False
# price_min_x               False
# dtype: bool

# %%
h = dataa[dataa['propertytype_name_en_x']=='Detached House'] 
h
# Out:
#           province_name_en propertytype_name_en_x  price_min_x
# 9               Chiang Mai         Detached House    3150000.0
# 10              Chiang Mai         Detached House    3150000.0
# 11              Chiang Mai         Detached House    3150000.0
# 12              Chiang Mai         Detached House    2800000.0
# 13              Chiang Mai         Detached House    2800000.0
# ...                    ...                    ...          ...
# 53718    Nakhon Ratchasima         Detached House    1500000.0
# 53719            Khon Kaen         Detached House    2690000.0
# 53720          Phetchaburi         Detached House    2450000.0
# 53721  Prachuap Khiri Khan         Detached House    5200000.0
# 53728              Bangkok         Detached House    3200000.0
#
# [17336 rows x 3 columns]

# %%
cd = dataa[dataa['propertytype_name_en_x']=='Condo'] 
cd
# Out:
#         province_name_en propertytype_name_en_x  price_min_x
# 0                Bangkok                  Condo    2500000.0
# 1                Bangkok                  Condo    1390000.0
# 2                Bangkok                  Condo    1990000.0
# 19            Chiang Mai                  Condo    1600000.0
# 22            Nonthaburi                  Condo     170000.0
# ...                  ...                    ...          ...
# 53664            Bangkok                  Condo     900000.0
# 53665  Nakhon Ratchasima                  Condo     340000.0
# 53683            Bangkok                  Condo    2340000.0
# 53690             Phuket                  Condo    1450000.0
# 53704         Nonthaburi                  Condo    1890000.0
#
# [10993 rows x 3 columns]

# %%
all = pd.concat([h,cd])

# %%
cm = all[all['province_name_en']=='Chiang Mai']

# %%
bkk = all[all['province_name_en']=='Bangkok']

# %%
kk = all[all['province_name_en']=='Khon Kaen']

# %%
hcm = cm[cm['propertytype_name_en_x']=='Detached House'] 
hcm
# Out:
#       province_name_en propertytype_name_en_x  price_min_x
# 9           Chiang Mai         Detached House    3150000.0
# 10          Chiang Mai         Detached House    3150000.0
# 11          Chiang Mai         Detached House    3150000.0
# 12          Chiang Mai         Detached House    2800000.0
# 13          Chiang Mai         Detached House    2800000.0
# ...                ...                    ...          ...
# 53609       Chiang Mai         Detached House    5500000.0
# 53611       Chiang Mai         Detached House   47000000.0
# 53613       Chiang Mai         Detached House    1590000.0
# 53615       Chiang Mai         Detached House    2500000.0
# 53699       Chiang Mai         Detached House    1590000.0
#
# [2140 rows x 3 columns]

# %%
cdcm = cm[cm['propertytype_name_en_x']=='Condo'] 
cdcm
# Out:
#       province_name_en propertytype_name_en_x  price_min_x
# 19          Chiang Mai                  Condo    1600000.0
# 119         Chiang Mai                  Condo    3180000.0
# 123         Chiang Mai                  Condo    4900000.0
# 124         Chiang Mai                  Condo    3981575.0
# 155         Chiang Mai                  Condo    2900000.0
# ...                ...                    ...          ...
# 52766       Chiang Mai                  Condo     690000.0
# 52796       Chiang Mai                  Condo    2800000.0
# 53282       Chiang Mai                  Condo     699000.0
# 53357       Chiang Mai                  Condo     700000.0
# 53537       Chiang Mai                  Condo    2192000.0
#
# [635 rows x 3 columns]

# %%
hbkk = bkk[bkk['propertytype_name_en_x']=='Detached House'] 
hbkk
# Out:
#       province_name_en propertytype_name_en_x  price_min_x
# 27             Bangkok         Detached House   11700000.0
# 28             Bangkok         Detached House    9900000.0
# 29             Bangkok         Detached House   12100000.0
# 30             Bangkok         Detached House   12600000.0
# 62             Bangkok         Detached House   36900000.0
# ...                ...                    ...          ...
# 53691          Bangkok         Detached House    3000000.0
# 53697          Bangkok         Detached House    4900000.0
# 53701          Bangkok         Detached House    2000000.0
# 53705          Bangkok         Detached House    6190000.0
# 53728          Bangkok         Detached House    3200000.0
#
# [3167 rows x 3 columns]

# %%
cdbkk = bkk[bkk['propertytype_name_en_x']=='Condo'] 
cdbkk
# Out:
#       province_name_en propertytype_name_en_x  price_min_x
# 0              Bangkok                  Condo    2500000.0
# 1              Bangkok                  Condo    1390000.0
# 2              Bangkok                  Condo    1990000.0
# 81             Bangkok                  Condo    4008000.0
# 82             Bangkok                  Condo    2400000.0
# ...                ...                    ...          ...
# 53591          Bangkok                  Condo     890000.0
# 53602          Bangkok                  Condo     390000.0
# 53644          Bangkok                  Condo     820000.0
# 53664          Bangkok                  Condo     900000.0
# 53683          Bangkok                  Condo    2340000.0
#
# [5489 rows x 3 columns]

# %%
hkk = kk[kk['propertytype_name_en_x']=='Detached House'] 
hkk
# Out:
#       province_name_en propertytype_name_en_x  price_min_x
# 37           Khon Kaen         Detached House     990000.0
# 38           Khon Kaen         Detached House    1530000.0
# 39           Khon Kaen         Detached House    1350000.0
# 80           Khon Kaen         Detached House    2200000.0
# 531          Khon Kaen         Detached House    4423000.0
# ...                ...                    ...          ...
# 53342        Khon Kaen         Detached House    2990000.0
# 53343        Khon Kaen         Detached House    2590000.0
# 53489        Khon Kaen         Detached House    4700000.0
# 53700        Khon Kaen         Detached House    2690000.0
# 53719        Khon Kaen         Detached House    2690000.0
#
# [719 rows x 3 columns]

# %%
cdkk = kk[kk['propertytype_name_en_x']=='Condo'] 
cdkk
# Out:
#       province_name_en propertytype_name_en_x  price_min_x
# 484          Khon Kaen                  Condo    2240000.0
# 485          Khon Kaen                  Condo    2190000.0
# 486          Khon Kaen                  Condo    1490000.0
# 487          Khon Kaen                  Condo    1290000.0
# 798          Khon Kaen                  Condo    1450000.0
# ...                ...                    ...          ...
# 46550        Khon Kaen                  Condo    1730000.0
# 50156        Khon Kaen                  Condo     650000.0
# 51855        Khon Kaen                  Condo    2004000.0
# 51856        Khon Kaen                  Condo    1420000.0
# 52630        Khon Kaen                  Condo     590000.0
#
# [112 rows x 3 columns]

# %%
from matplotlib import pyplot as plt

# %%
plt.subplot(2,3,1)
KKH = plt.boxplot(hkk['price_min_x'],vert=False,showmeans=True,meanprops={'marker':'o'})
plt.title('House Price in KK');
#plot ราคาบ้านขอนแก่น
plt.subplot(2,3,2)
BKKH = plt.boxplot(hbkk['price_min_x'],vert=False,showmeans=True,meanprops={'marker':'o'})
plt.title('House Price in BKK');
#plot ราคาบ้านกรุงเทพ
plt.subplot(2,3,3)
CMH = plt.boxplot(hcm['price_min_x'],vert=False,showmeans=True,meanprops={'marker':'o'})
plt.title('House Price in CHM');
#plot ราคาบ้านเชียงใหม่
plt.subplot(2,3,4)
KKCD = plt.boxplot(cdkk['price_min_x'],vert=False,showmeans=True,meanprops={'marker':'o'})
plt.title('Condo Price in KK');
#plot ราคาคอนโดขอนแก่น
plt.subplot(2,3,5)
BKKCD = plt.boxplot(cdbkk['price_min_x'],vert=False,showmeans=True,meanprops={'marker':'o'})
plt.title('Condo Price in BKK');
#plot ราคาคอนโดกรุงเทพ
plt.subplot(2,3,6)
CMCD = plt.boxplot(cdcm['price_min_x'],vert=False,showmeans=True,meanprops={'marker':'o'})
plt.title('Condo Price in CHM');
#plot ราคาคอนโดเชียงใหม่
